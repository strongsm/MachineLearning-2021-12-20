# %% [markdown]
# # DataFrame - 합성(merge, join)

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame({
    '고객번호' : [1001,1002,1003,1004,1005,1006,1007],
    '이름': ['둘리', '도우너', '또치', '길동', '희동', '마이콜', '영희']
}, columns=['고객번호','이름'])
df1
# Out:
#    고객번호   이름
# 0  1001   둘리
# 1  1002  도우너
# 2  1003   또치
# 3  1004   길동
# 4  1005   희동
# 5  1006  마이콜
# 6  1007   영희

# %%
df2 = pd.DataFrame({
    '고객번호' : [1001,1001,1005,1006,1008,1001],
    '금액': [10000, 20000, 15000, 5000, 100000, 30000]
}, columns=['고객번호','금액'])
df2
# Out:
#    고객번호      금액
# 0  1001   10000
# 1  1001   20000
# 2  1005   15000
# 3  1006    5000
# 4  1008  100000
# 5  1001   30000

# %%
# Inner Join
pd.merge(df1, df2)
# Out:
#    고객번호   이름     금액
# 0  1001   둘리  10000
# 1  1001   둘리  20000
# 2  1001   둘리  30000
# 3  1005   희동  15000
# 4  1006  마이콜   5000

# %%
# Left Outer Join

pd.merge(df1, df2, how='left')
# Out:
#    고객번호   이름       금액
# 0  1001   둘리  10000.0
# 1  1001   둘리  20000.0
# 2  1001   둘리  30000.0
# 3  1002  도우너      NaN
# 4  1003   또치      NaN
# 5  1004   길동      NaN
# 6  1005   희동  15000.0
# 7  1006  마이콜   5000.0
# 8  1007   영희      NaN

# %%
# Rrignt Outer Join
pd.merge(df1, df2, how='right')
# Out:
#    고객번호   이름      금액
# 0  1001   둘리   10000
# 1  1001   둘리   20000
# 2  1005   희동   15000
# 3  1006  마이콜    5000
# 4  1008  NaN  100000
# 5  1001   둘리   30000

# %%
# Full Outer Join
pd.merge(df1, df2, how='outer')
# Out:
#    고객번호   이름        금액
# 0  1001   둘리   10000.0
# 1  1001   둘리   20000.0
# 2  1001   둘리   30000.0
# 3  1002  도우너       NaN
# 4  1003   또치       NaN
# 5  1004   길동       NaN
# 6  1005   희동   15000.0
# 7  1006  마이콜    5000.0
# 8  1007   영희       NaN
# 9  1008  NaN  100000.0

# %% [markdown]
# - Join method

# %%
df3 = df1.set_index('고객번호')
df4 = df2.set_index('고객번호')
df3.join(df4)                    # left outer join이 defualt
# Out:
#        이름       금액
# 고객번호
# 1001   둘리  10000.0
# 1001   둘리  20000.0
# 1001   둘리  30000.0
# 1002  도우너      NaN
# 1003   또치      NaN
# 1004   길동      NaN
# 1005   희동  15000.0
# 1006  마이콜   5000.0
# 1007   영희      NaN

# %% [markdown]
# # 과제

# %%
cctv = pd.read_csv('서울시CCTV설치운영현황(자치구)_년도별_210731기준.csv',
                    skiprows=1, encoding='euc-kr')
cctv.head()
# Out:
#     구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 1  종로구   1,772      813      0      0    210    150      1    261     85
# 2  중 구   2,333       16    114     87     77    236    240    372    386
# 3  용산구   2,383       34     71    234    125    221    298    351    125
# 4  성동구   3,602      448    125    212    105    339    310    874    390
#
#     2019년   2020년  2021년
# 0  11,961  11,132  1,608
# 1       9     200     43
# 2     155     361    289
# 3     307     617      0
# 4     262     461     76

# %%
pop = pd.read_csv('서울시주민등록인구(구별)통계.txt', sep='\t', encoding='utf-8')
pop.head()
# Out:
#          기간  자치구         세대         인구       인구.1       인구.2       인구.3  \
# 0        기간  자치구         세대         합계         합계         합계        한국인
# 1        기간  자치구         세대          계         남자         여자          계
# 2  2021.2/4   합계  4,405,638  9,795,426  4,756,178  5,039,248  9,565,990
# 3  2021.2/4  종로구     73,525    155,106     75,009     80,097    146,029
# 4  2021.2/4   중구     62,897    132,259     64,526     67,733    123,016
#
#         인구.4       인구.5     인구.6     인구.7     인구.8  세대당인구   65세이상고령자
# 0        한국인        한국인    등록외국인    등록외국인    등록외국인  세대당인구   65세이상고령자
# 1         남자         여자        계       남자       여자  세대당인구   65세이상고령자
# 2  4,649,442  4,916,548  229,436  106,736  122,700   2.17  1,576,971
# 3     70,985     75,044    9,077    4,024    5,053   1.99     27,605
# 4     60,019     62,997    9,243    4,507    4,736   1.96     23,980

# %%
pop.set_index('자치구').head()
# Out:
#            기간         세대         인구       인구.1       인구.2       인구.3  \
# 자치구
# 자치구        기간         세대         합계         합계         합계        한국인
# 자치구        기간         세대          계         남자         여자          계
# 합계   2021.2/4  4,405,638  9,795,426  4,756,178  5,039,248  9,565,990
# 종로구  2021.2/4     73,525    155,106     75,009     80,097    146,029
# 중구   2021.2/4     62,897    132,259     64,526     67,733    123,016
#
#           인구.4       인구.5     인구.6     인구.7     인구.8  세대당인구   65세이상고령자
# 자치구
# 자치구        한국인        한국인    등록외국인    등록외국인    등록외국인  세대당인구   65세이상고령자
# 자치구         남자         여자        계       남자       여자  세대당인구   65세이상고령자
# 합계   4,649,442  4,916,548  229,436  106,736  122,700   2.17  1,576,971
# 종로구     70,985     75,044    9,077    4,024    5,053   1.99     27,605
# 중구      60,019     62,997    9,243    4,507    4,736   1.96     23,980

# %%
pop.drop(index=[1], inplace=True)
pop.head()
# Out:
#          기간  자치구         세대         인구       인구.1       인구.2       인구.3  \
# 2  2021.2/4   합계  4,405,638  9,795,426  4,756,178  5,039,248  9,565,990
# 3  2021.2/4  종로구     73,525    155,106     75,009     80,097    146,029
# 4  2021.2/4   중구     62,897    132,259     64,526     67,733    123,016
# 5  2021.2/4  용산구    111,650    240,665    116,858    123,807    226,378
# 6  2021.2/4  성동구    134,542    295,767    143,927    151,840    289,162
#
#         인구.4       인구.5     인구.6     인구.7     인구.8 세대당인구   65세이상고령자
# 2  4,649,442  4,916,548  229,436  106,736  122,700  2.17  1,576,971
# 3     70,985     75,044    9,077    4,024    5,053  1.99     27,605
# 4     60,019     62,997    9,243    4,507    4,736  1.96     23,980
# 5    108,948    117,430   14,287    7,910    6,377  2.03     38,884
# 6    141,042    148,120    6,605    2,885    3,720  2.15     45,591

# %%
pop['구별'] = cctv.apply(lambda x: )
pop

# %%
cctv.set_index('구분').head()
# Out:
#          총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년   2019년  \
# 구분
# 계    77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876  11,961
# 종로구   1,772      813      0      0    210    150      1    261     85       9
# 중 구   2,333       16    114     87     77    236    240    372    386     155
# 용산구   2,383       34     71    234    125    221    298    351    125     307
# 성동구   3,602      448    125    212    105    339    310    874    390     262
#
#       2020년  2021년
# 구분
# 계    11,132  1,608
# 종로구     200     43
# 중 구     361    289
# 용산구     617      0
# 성동구     461     76

# %%
cctv.drop(index=[0], inplace=True)
cctv.head()
# Out:
#     구분     총계 2012년 이전 2012년 2013년 2014년 2015년 2016년 2017년 2018년 2019년 2020년  \
# 1  종로구  1,772      813     0     0   210   150     1   261    85     9   200
# 2  중 구  2,333       16   114    87    77   236   240   372   386   155   361
# 3  용산구  2,383       34    71   234   125   221   298   351   125   307   617
# 4  성동구  3,602      448   125   212   105   339   310   874   390   262   461
# 5  광진구  2,588       35    57   100   187    98    52   675   465   712   175
#
#   2021년
# 1    43
# 2   289
# 3     0
# 4    76
# 5    32

# %%
cctv = pd.DataFrame({
    'data1':range(6),
    'key':list('aabbcc')
})

pop = pd.DataFrame({
    'data2':range(3),
    'key':list('cad')
})

# %%
merge = pd.merge(cctv, pop, left_index=True, right_index=True)
merge.head()
# Out:
#      구분     총계 2012년 이전 2012년 2013년 2014년 2015년 2016년 2017년 2018년  ...  \
# 2   중 구  2,333       16   114    87    77   236   240   372   386  ...
# 3   용산구  2,383       34    71   234   125   221   298   351   125  ...
# 4   성동구  3,602      448   125   212   105   339   310   874   390  ...
# 5   광진구  2,588       35    57   100   187    98    52   675   465  ...
# 6  동대문구  2,497    1,090   146    60    29   111   233   136   197  ...
#
#         인구.1       인구.2       인구.3       인구.4       인구.5     인구.6     인구.7  \
# 2  4,756,178  5,039,248  9,565,990  4,649,442  4,916,548  229,436  106,736
# 3     75,009     80,097    146,029     70,985     75,044    9,077    4,024
# 4     64,526     67,733    123,016     60,019     62,997    9,243    4,507
# 5    116,858    123,807    226,378    108,948    117,430   14,287    7,910
# 6    143,927    151,840    289,162    141,042    148,120    6,605    2,885
#
#       인구.8 세대당인구   65세이상고령자
# 2  122,700  2.17  1,576,971
# 3    5,053  1.99     27,605
# 4    4,736  1.96     23,980
# 5    6,377  2.03     38,884
# 6    3,720  2.15     45,591
#
# [5 rows x 27 columns]

# %%
cctv['최근증가율'] = cctv.apply(lambda x: x.max() - x.min(), axis=1)
cctv
